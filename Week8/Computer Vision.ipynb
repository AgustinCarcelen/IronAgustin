# %% [markdown]
# # In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue.

# %% [markdown]
# https://medium.com/dain-studios/to-what-extent-does-computer-vision-ai-need-ethics-84c0816f565

# %% [markdown]
# I think the article makes a lot of sense, it is good to advance with technology, but you have to take into account aspects such as privacy. On the other hand, I also think that to improve you have to take risks, but it is easy to say things when they do not affect you.

# %% [markdown]
# # use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint

# %%
# %matplotlib inline
from IPython.display import Image
Image('cvsnow.png')

# %% [markdown]
# I think he has done quite well, you can see how it is in the snow and it seems that the ground is flat. On the other hand, I couldn't tell you if she is a woman or not, or if there is only one, since there seems to be more than two legs.

# %% [markdown]
# 1. Make graphics with the images
# 2. Separate the good images from the bad
# 3. Generates images and groups them according to their case: dog and cat
# 4. Tag all your images
# 5. Separate your images into training and test
# 6. Create a neural network
# 7. Train your model
# 8. Show training results
# 9. Augment the data to see how well your model works
