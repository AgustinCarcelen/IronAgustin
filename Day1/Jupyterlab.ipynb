# %% [markdown]
# # Holidays of  Agustin Carelen

# %% [markdown]
# ## This notebook is to be able to choose the vacations I want

# %% [markdown]
# ### 1. Personal information

# %% [markdown]
# #### 1.1 Name

# %%
#Input to get the name
name = input("Introduce your name: ")
# Out:
# Introduce your name: Agustin

# %% [markdown]
# #### 1.2 Face

# %% [markdown]
# Photo of the person requesting the vacation
# ![fondo5.jpg](attachment:fondo5.jpg)

# %% [markdown]
# ### 2. Date and destination

# %%
#different inputs to save the data
print("Enter the date on which you want the vacation (all with numbers - dd/mm/yyyy) and the destination")

sday = input("Start day - dd: ")
fday = input("Finish day - dd: ")
mon = input("Month - mm: ")
year = input("Year - yyyy: ")
dest= input("Destination: ")
# Out:
# Enter the date on which you want the vacation (all with numbers - dd/mm/yyyy) and the destination
# Start day - dd: 10
# Finish day - dd: 24
# Month - mm: 08
# Year - yyyy: 2022
# Destination: Thailand

# %% [markdown]
# ### 3. Details

# %% [markdown]
# #### 3.1 Photo

# %% [markdown]
# Vacation destination photo
# ![Tai.jpg](attachment:Tai.jpg)

# %% [markdown]
# #### 3.2 HighlightH

# %%
print("Say 3 things you want to travel to", dest)

top = ['','','']
i = 0

#small loop to store the 3 highlights
while i < 3:
    top[i] = input ()
    i += 1
# Out:
# Say 3 things you want to travel to Thailand
# See golden buddhas
# Go scuba diving
# Touch elephants

# %% [markdown]
# #### 3.3 Video

# %% [markdown]
# Video of the desired place:
# https://www.youtube.com/watch?v=Yj3CsnYA4A0&ab_channel=MundoXDescubrir-RaulyDiana
