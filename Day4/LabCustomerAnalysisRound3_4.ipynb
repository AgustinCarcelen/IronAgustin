# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import statistics as stats
import time
from datetime import date

data = pd.read_csv('marketing_customer_analysis.txt',sep=',')
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %% [markdown]
# # Show the dataframe shape

# %%
data.shape
# Out:
# (10910, 26)

# %% [markdown]
# # Standardize header names.

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type]
# Index: []
#
# [0 rows x 26 columns]

# %%
def standardize_header(data):
    cols = []
    for i in range (len(data.columns)):
        cols.append(data.columns[i].lower())
    data.columns = cols

    data.columns = data.columns.str.replace(" ","_")

    new_names = {'unnamed:_0':'id',}
    data.rename(columns=new_names,inplace=True)

standardize_header(data)

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [id, customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # Which columns are numerical?

# %%
data.select_dtypes([np.number])
# Out:
#           id  customer_lifetime_value  income  monthly_premium_auto  \
# 0          0              4809.216960   48029                    61
# 1          1              2228.525238       0                    64
# 2          2             14947.917300   22139                   100
# 3          3             22332.439460   49078                    97
# 4          4              9025.067525   23675                   117
# ...      ...                      ...     ...                   ...
# 10905  10905             15563.369440       0                   253
# 10906  10906              5259.444853   61146                    65
# 10907  10907             23893.304100   39837                   201
# 10908  10908             11971.977650   64195                   158
# 10909  10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# ...

# %% [markdown]
# # Which columns are categorical?

# %%
data.select_dtypes([object])
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# # Check and deal with NaN values.

# %%
# show if there is any null value
data.isnull().values.any()
# Out:
# True

# %%
#shows how many null values there are
data.isnull().sum().sum()
# Out:
# 9254

# %%
#shows where null values are found
nullvalues = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nullvalues = nullvalues.rename(columns={'index':'header',0:'prop_nulls'})
nullvalues
# Out:
#                                prop_nulls
# id                                   0.00
# customer                             0.00
# state                                5.78
# customer_lifetime_value              0.00
# response                             5.78
# coverage                             0.00
# education                            0.00
# effective_to_date                    0.00
# employmentstatus                     0.00
# gender                               0.00
# income                               0.00
# location_code                        0.00
# marital_status                       0.00
# monthly_premium_auto                 0.00
# months_since_last_claim              5.80
# months_since_policy_inception        0.00
# number_of_open_complaints            5.80
# number_of_policies                   0.00
# policy_type                          0.00
# policy                               0.00
# renew_offer_type                     0.00
# ...

# %%
#we can delete the column because it has half of the values in null
def delete_column(data,column):
    data = data.drop([column],axis=1)
    return data

data = delete_column(data,'vehicle_type')

# %%
#fill null values of categorical columns with unknown
def fillnull_cate(data,column):
    data[column] = data[column].fillna('unknown')

fillnull_cate(data,'state')
fillnull_cate(data,'response')
fillnull_cate(data,'vehicle_class')
fillnull_cate(data,'vehicle_size')

# %%
#fill null values of numerical columns with median
def fillnull_num(data,column):
    data[column] = data[column].fillna(data[column].median())

fillnull_num(data,'months_since_last_claim')
fillnull_num(data,'number_of_open_complaints')

# %%
#to improve
#for x in data.select_dtypes([object]):
#    data.select_dtypes([object])=data.select_dtypes([object]).fillna('unknown')

# %% [markdown]
# # Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
data['effective_to_date']=pd.to_datetime(data['effective_to_date'], errors='coerce')

# %%
data['months']=pd.DatetimeIndex(data['effective_to_date']).month

# %%
var = [1,2,3]
data[data.months.isin(var)]
# Out:
#           id customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877     unknown              6857.519928  unknown     Basic
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %% [markdown]
# # LabCustomerAnalysisRound3 starts here - imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Show DataFrame info.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %% [markdown]
# # Describe DataFrame.

# %%
data.describe()
# Out:
#                  id  customer_lifetime_value        income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        monthly_premium_auto  months_since_last_claim  \
# count          10910.000000             10910.000000
# mean              93.196059                15.082401
# std               34.442532                 9.787208
# min               61.000000                 0.000000
# 25%               68.000000                 7.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %% [markdown]
# # Show a plot of the total number of responses (for each response type - "Yes"/"No").

# %%
# da=data[(data['response']=='Yes')|(data['response']=='No')] its the same
da=data.query('response=="Yes"|response=="No"')
da['response'].value_counts().plot(kind='bar',color='grey')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Show a plot of the rate of the response types by each Sales Channel.

# %%
da.groupby('sales_channel')['response'].value_counts().unstack().plot.bar(ylabel='Responses');

# %% [markdown]
# # Show a plot of the distribution of the Total Claim Amount, broken down by response type. Try a boxplot and distribution plot, for each response type. For the distribution plot, try to plot both kinds of responses in one chart (seaborn's histplot, using the 'hue' parameter is very convenient here).

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=da['total_claim_amount'],y=da['response']);

# %%
plt.figure(figsize=(10,5))
da.groupby('response')['total_claim_amount'].hist(bins=20, legend=True);

# %% [markdown]
# # Create similar plots like in the task before, but for Income.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=da['income'],y=da['response']);

# %%
plt.figure(figsize=(10,5))
da.groupby('response')['income'].hist(bins=20, legend=True);

# %% [markdown]
# # Create a scatterplot between Total Claim Amount and Income. Play around with the settings of the scatterplot (markersize, alpha level, ...) and in doing so try to identify more features within the data just visually. You can also try different seaborn plots. Check for example this link which explains how to avoid overplotting.

# %%
sns.scatterplot(x='income',y='total_claim_amount',data=da, color=".1", marker=".");

# %% [markdown]
# # LabCustomerAnalysisRound4 starts here

# %% [markdown]
# # Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
datanum = data.select_dtypes([np.number])
datacat = data.select_dtypes([object])
datanum
# Out:
#           id  customer_lifetime_value  income  monthly_premium_auto  \
# 0          0              4809.216960   48029                    61
# 1          1              2228.525238       0                    64
# 2          2             14947.917300   22139                   100
# 3          3             22332.439460   49078                    97
# 4          4              9025.067525   23675                   117
# ...      ...                      ...     ...                   ...
# 10905  10905             15563.369440       0                   253
# 10906  10906              5259.444853   61146                    65
# 10907  10907             23893.304100   39837                   201
# 10908  10908             11971.977650   64195                   158
# 10909  10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# ...

# %% [markdown]
# # Now we will try to check the normality of the numerical variables visually

# %% [markdown]
# ## Use seaborn library to construct distribution plots for the numerical variables

# %%
#sns.pairplot(datanum)

n_rows=4
n_cols=3
# Using for to create the subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(15, 15))
for i, column in enumerate(datanum.columns):
    sns.histplot(datanum[column],ax=axes[i//n_cols,i%n_cols])

# %% [markdown]
# ## Use Matplotlib to construct histograms

# %%
datanum.hist(figsize=(15,15),bins=50,layout=(4,3));

# %% [markdown]
# ## Do the distributions for different numerical variables look like a normal distribution?

# %% [markdown]
# No, because the normal distribution looks like a Gaussian bell

# %% [markdown]
# # For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

# %%
da=datanum.corr() #will only work for numerical fields
da
# Out:
#                                      id  customer_lifetime_value    income  \
# id                             1.000000                 0.001355  0.008910
# customer_lifetime_value        0.001355                 1.000000  0.028306
# income                         0.008910                 0.028306  1.000000
# monthly_premium_auto           0.000863                 0.403069 -0.009788
# months_since_last_claim        0.008228                 0.015874 -0.022708
# months_since_policy_inception  0.012795                 0.016960 -0.005903
# number_of_open_complaints      0.008943                -0.030616  0.008425
# number_of_policies             0.002319                 0.016024 -0.009960
# total_claim_amount            -0.000593                 0.232626 -0.354141
# months                         0.004755                -0.009234 -0.000443
#
#                                monthly_premium_auto  months_since_last_claim  \
# ...

# %% [markdown]
# # Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
sns.heatmap(da, annot=True);

# %%
mask=np.zeros_like(da)
mask[np.triu_indices_from(mask)] = True
fig, ax= plt.subplots(figsize=(12,10))
ax= sns.heatmap(da, mask=mask, annot=True)
